                   0.9882094950318674, 0.9881707073640752, 0.9881735454861088, 0.9881252974115381, 0.9881092147200146,
                   0.9880675889301889, 0.9880751572556117, 0.9880619126861216, 0.9879881215132488, 0.9880297473030746],
    "12 Clients": [0.9856069371270826, 0.9867507003066118, 0.987132900740466, 0.9871906092218153, 0.9873949540082324,
                   0.9875292917844881, 0.9878367550047917, 0.988046776035276, 0.9881366498996724, 0.9882586891471159,
                   0.9882984228555859, 0.988317343669143, 0.9883069372216866, 0.9883069372216866, 0.9883532932149016,
                   0.9883088293030424, 0.9882672035132166, 0.9883107213843981, 0.988278556001351, 0.9883343724013445],
    "13 Clients": [0.9854555706186254, 0.9867724592422025, 0.9873098103472253, 0.9874725293438167, 0.9875652413302467,
                   0.9876768741302339, 0.9878528376963153, 0.988152732591196, 0.9882662574725388, 0.9883797823538817,
                   0.9882634193505052, 0.9882899084894853, 0.9883409946860895, 0.9883391026047338, 0.988291800570841,
                   0.9883031530589752, 0.9882974768149081, 0.9882189554386459, 0.9882340920894916, 0.9882076029505117],
    "14 Clients": [0.9844376308492513, 0.9866721789303496, 0.9872748068421446, 0.9874053604556888, 0.9874933422387295,
                   0.9877771544420867, 0.9878954095268189, 0.9880524522793431, 0.9882009806657667, 0.9881697613233974,
                   0.9881735454861088, 0.9881489484284846, 0.9882217935606795, 0.9882076029505117, 0.9881943583810217,
                   0.9881546246725517, 0.988152732591196, 0.9881546246725517, 0.9881725994454309, 0.9881830058928874],
    "15 Clients": [0.9854432720898133, 0.9867970562998267, 0.987298457859091, 0.9874261733506017, 0.9874517164489038,
                   0.9877109315946367, 0.9878973016081746, 0.9881631390386524, 0.9881707073640752, 0.9882567970657602,
                   0.9883163976284652, 0.9882284158454245, 0.9882492287403374, 0.9882397683335588, 0.9882293618861023,
                   0.9883078832623645, 0.9882605812284717, 0.9882066569098338, 0.9882132791945788, 0.9881413801030616]
}

import pandas as pd
import matplotlib.pyplot as plt

# Assuming your data is in a pandas DataFrame named 'df'

# Plotting
df = pd.DataFrame(data)
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# Number of lines to plot
num_lines = len(df.columns) - 1  # Exclude the "Rounds" column

# Generate a colormap
colors = cm.tab20(np.linspace(0, 1, num_lines))  # Use tab20 colormap for distinct colors

plt.figure(figsize=(14,20))  # Keep the aspect ratio visually appealing

# Plot each line with a unique color
for i, column in enumerate(df.columns[1:]):
    plt.plot(df["Rounds"], df[column], label=column, color=colors[i], linewidth=2)

# Title and axis labels with professional formatting
plt.title("Accuracy v/s Rounds", fontsize=16, fontweight='bold')
plt.xlabel("Rounds", fontsize=14)
plt.ylabel("Accuracy (%)", fontsize=14)

# Ensure ticks are integers
plt.xticks(ticks=range(int(df["Rounds"].min()), int(df["Rounds"].max()) + 1), fontsize=12)
plt.yticks(fontsize=12)

# Position legend inside the plot
plt.legend(title="Clients", loc="lower right", fontsize=12, title_fontsize=13)

# Set grid lines to dashed and slightly lighter
plt.grid(linestyle='--', alpha=0.7)

# Ensure layout is tight for publication
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

#
    11: [0.9041703279499843, 0.9404197040935168, 0.9402186107638555, 0.9407149642944824, 0.9376218323586745, 0.9407679217187832, 0.9396482305573215, 0.9402850823818242, 0.9388809242705347, 0.9381288149863186, 0.9373180753023759, 0.9365659109991604, 0.9368062920687591, 0.9362133008751128, 0.9366326648527697, 0.9352493111071529, 0.9353550807406553, 0.9355829829179032, 0.9356765666173243, 0.9340937366049492],
}

# Assuming precision_data is a dictionary with clients as keys and precision values as lists
num_clients = len(precision_data)  # Number of distinct clients

# Generate a colormap for distinct colors
colors = cm.tab20(np.linspace(0, 1, num_clients))  # Use tab20 for distinct colors

# Plotting
plt.figure(figsize=(14,10))  # Adjusted figure size to 14x10 for a more standard aspect ratio

# Plot each client's precision values with unique color
for i, (client, precision_values) in enumerate(precision_data.items()):
    plt.plot(precision_values, label=f'Client {client}', color=colors[i], linewidth=2)

# Title and axis labels with professional formatting
plt.title("Precision v/s Rounds", fontsize=16, fontweight='bold')
plt.xlabel('Rounds', fontsize=14)
plt.ylabel('Precision', fontsize=14)

# Set x-axis to show client numbers (x-axis as clients)
plt.xticks(np.arange(0, len(next(iter(precision_data.values()))) + 1, step=2), fontsize=12)  # Show integer ticks
plt.yticks(fontsize=12)

# Position legend inside the plot (lower right)
plt.legend(title="Clients", loc="lower right", fontsize=12, title_fontsize=13)

# Set grid lines to dashed and slightly lighter
plt.grid(linestyle='--', alpha=0.7)

# Ensure layout is tight and suitable for publication
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for each client
data = {
    4: [0.9168499000293543, 0.9225713158932562, 0.925567752012234, 0.9288864388092613,
        0.9310263451471724, 0.9328214356274396, 0.9337084747205054, 0.9342112244140024,
        0.9352573525523747, 0.9360448852270388, 0.9364514274563166, 0.9370413490462167,
        0.9371462866348336, 0.9372492444425724, 0.9374546143402899, 0.9375818971188001,
        0.9375647355110753, 0.9376764135422525, 0.9382382755668538, 0.9379767583583752],
    5: [0.9193467764527522, 0.9246469268096529, 0.9286163877277642, 0.9306938099436296,
        0.9321970745416995, 0.9331481049439012, 0.9338219740237763, 0.9342307225706404,
        0.9346444796563506, 0.9345492433012692, 0.9352906215319234, 0.935184941839379,
        0.9357531341215011, 0.9359877842086759, 0.9363177607352309, 0.9362170895604597,
        0.9364541477385986, 0.9364371004703895, 0.9366310567084651, 0.9370454080642708],
    6: [0.9216333264590637, 0.92733708769107, 0.9296258189708022, 0.9317866559366363,
        0.9327508981846383, 0.9327905676892737, 0.9331535593148924, 0.9333550731879218,
        0.9337931832161802, 0.9340499419462964, 0.934537127490835, 0.9344572238853002,
        0.9345337147956639, 0.9347751945305819, 0.9351180672841902, 0.9350799177748877,
        0.9349005709372493, 0.9350168773717424, 0.9351872711174446],
    7: [0.9226037542754033, 0.9262934391771497, 0.9302566652034335, 0.9316107095527478,
        0.9319974531275489, 0.9318687562141944, 0.9323830293835667, 0.932320071524363,
        0.9330975351723485, 0.9333866773354671, 0.9338775166726274, 0.9344854228094795,
        0.9344471589565766, 0.9352309429404196, 0.9351488237237127, 0.9349442086653622,
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# Ensure all lists have 20 values
for clients, f1_scores in data.items():
    while len(f1_scores) < 20:
        f1_scores.append(f1_scores[-1])

# Number of clients to plot
num_clients = len(data)

# Generate a colormap for distinct colors
colors = cm.tab20(np.linspace(0, 1, num_clients))  # Use tab20 colormap for distinct colors

# Plotting the data with adjusted figure size
plt.figure(figsize=(14,20))  # Adjusted figure size to 7x10 aspect ratio

# Plot each client's F1 scores with a unique color
for i, (clients, f1_scores) in enumerate(data.items()):
    plt.plot(range(1, 21), f1_scores, label=f'{clients} clients', color=colors[i], linewidth=2)

# Title and axis labels with professional formatting
plt.title('F1 Score v/s Rounds', fontsize=16, fontweight='bold')
plt.xlabel('Rounds', fontsize=14)
plt.ylabel('F1 Score', fontsize=14)

# Ensure ticks are integers
plt.xticks(range(1, 21), fontsize=12)
plt.yticks(fontsize=12)

# Position the legend inside the plot (lower right)
plt.legend(title='Number of Clients', loc="lower right", fontsize=12, title_fontsize=13)

# Set grid lines to dashed and slightly lighter
plt.grid(linestyle='--', alpha=0.7)

# Ensure layout is tight and suitable for publication
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for each client group
Rounds = list(range(1, 21))

false_negatives_2_clients = [
    25696, 25492, 15615, 12382, 11975, 11443, 10899, 10238, 9917, 9597,
    9198, 8677, 8356, 8155, 8007, 7776, 7424, 7356, 7293, 7233
]
false_negatives_3_clients = [
    23443, 12889, 11495, 10864, 10087, 9493, 8961, 8378, 8145, 7773,
    7460, 7239, 7239, 7018, 6942, 6914, 6917, 6862, 6833, 6806
]
false_negatives_4_clients = [
    12926, 11480, 10659, 9761, 8902, 8348, 7919, 7655, 7259, 7024,
    6919, 6760, 6691, 6692, 6620, 6614, 6535, 6500, 6379, 6425
]
false_negatives_5_clients = [
    12012, 10616, 9389, 8604, 8131, 7702, 7405, 7137, 6923, 6897, 6784,
    6737, 6537, 6509, 6449, 6460, 6436, 6410, 6399, 6352
]
false_negatives_6_clients = [
    10785, 9245, 8505, 7699, 7295, 7246, 7108, 6968, 6889, 6802, 6729,
    6731, 6684, 6618, 6554, 6538, 6535, 6501, 6445, 6381
]
false_negatives_7_clients = [
    10053, 8881, 7750, 7472, 7139, 7127, 7197, 7058, 7055, 7042,
    6916, 6797, 6767, 6655, 6516, 6856, 6556, 6540, 6395, 6375
]
false_negatives_8_clients = [
    9004, 9542, 7906, 7536, 7250, 7113, 7054, 6877, 6861, 6764,
    6722, 6696, 6499, 6586, 6562, 6521, 6540, 6465, 6421, 6473
]
false_negatives_9_clients = [
    8111, 8770, 8482, 7717, 7696, 7339, 7250, 7184, 7275, 7097,
    6939, 6850, 6819, 6733, 6833, 6743, 6743, 6671, 6685, 6692
]
false_negatives_10_clients = [
    5810, 8388, 7652, 7536, 7403, 7142, 7076, 6916, 6940, 6845,
    6821, 6634, 6636, 6791, 6623, 6602, 6470, 6567, 6515, 6470
]
false_negatives_11_clients = [
    6175, 8489, 7700, 7567, 7192, 7245, 7012, 6840, 6630, 6555,
    6498, 6460, 6483, 6473, 6537, 6433, 6436, 6476, 6570, 6349
]
false_negatives_12_clients = [
    7031, 8355, 7784, 7647, 7509, 7282, 7134, 6869, 6566, 6722,
    6556, 6600, 6425, 6556, 6581, 6541, 6448, 6542, 6622, 6574
]
false_negatives_13_clients = [
    6761, 8482, 7698, 7560, 7142, 7057, 6686, 6586, 6641, 6664,
    6455, 6546, 6474, 6654, 6579, 6626, 6584, 6673, 6558, 6434
]
false_negatives_14_clients = [
    5952,9272,8014,7758,7376,7188,6965,6891,6876,6914,6774,
6860,6864,6793,6884,6802,6806,6803,6802,6915
]

false_negatives_15_clients = [
    6897, 8404, 7744, 7499, 7298, 7044, 6855, 6900, 6943, 6883,
    6805, 6851, 6746, 6597, 6654, 6642, 6648, 6697, 6719, 6724
]

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# Number of lines (clients) to plot
num_clients = 15  # As you have 15 client groups

# Generate a colormap for distinct colors
colors = cm.tab20(np.linspace(0, 1, num_clients))  # Use tab20 colormap for distinct colors

# Create a figure and axis with the new 7x10 aspect ratio
plt.figure(figsize=(14,20))  # Adjusted figure size to 7x10 aspect ratio

# Plot the false negatives for each client group with unique colors
client_data = [
    false_negatives_2_clients, false_negatives_3_clients, false_negatives_4_clients,
    false_negatives_5_clients, false_negatives_6_clients, false_negatives_7_clients,
    false_negatives_8_clients, false_negatives_9_clients, false_negatives_10_clients,
    false_negatives_11_clients, false_negatives_12_clients, false_negatives_13_clients,
    false_negatives_14_clients, false_negatives_15_clients
]

# Plot each client's false negatives with a distinct color
for i, data in enumerate(client_data, start=2):
    plt.plot(Rounds, data, label=f'{i} clients', color=colors[i-2], linewidth=2)

# Adding titles and labels with professional formatting
plt.title('False Negatives v/s Rounds', fontsize=16, fontweight='bold')
plt.xlabel('Rounds', fontsize=14)
plt.ylabel('False Negatives', fontsize=14)

# Ensure ticks are integers
plt.xticks(range(1, 21), fontsize=12)
plt.yticks(fontsize=12)

# Position the legend inside the plot (lower right)
plt.legend(title='Number of Clients', loc="upper right", fontsize=12, title_fontsize=13)

# Set grid lines to dashed and slightly lighter
plt.grid(linestyle='--', alpha=0.7)

# Ensure layout is tight and suitable for publication
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# Number of clients (assuming `data['Recall']` has values for multiple clients)
num_clients = len(data['Recall'])

# Generate a colormap for distinct colors
colors = cm.tab20(np.linspace(0, 1, num_clients))  # Use tab20 colormap for distinct colors

# Create the plot with the 7x10 aspect ratio
plt.figure(figsize=(14, 20))

# Plot recall values for each client with a distinct color
for i, recall_values in enumerate(data['Recall']):
    # Extract rounds dynamically based on the length of recall_values
    rounds = [val[0] for val in recall_values]
    recall_scores = [val[1] for val in recall_values]
    plt.plot(rounds, recall_scores, label=f'Client {i+1}', color=colors[i], linewidth=2)

# Title and axis labels with professional formatting
plt.title('Recall v/s Rounds', fontsize=16, fontweight='bold')
plt.xlabel('Rounds', fontsize=14)
plt.ylabel('Recall', fontsize=14)

# Ensure ticks are integers
plt.xticks(range(1, 21), fontsize=12)
plt.yticks(fontsize=12)

# Position the legend inside the plot (lower right)
plt.legend(title='Clients', loc="lower right", fontsize=12, title_fontsize=13)

# Set grid lines to dashed and slightly lighter
plt.grid(linestyle='--', alpha=0.7)

# Ensure layout is tight for publication
plt.tight_layout()

# Display the plot
plt.show()
